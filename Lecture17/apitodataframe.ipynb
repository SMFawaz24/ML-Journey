# %%
import pandas as pd
import requests

# %%
response = requests.get("API")

# %%
pd.DataFrame(response.json()['results']) # .head()

# %%
df = pd.DataFrame()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
for i in range(1,last+1):
    response = requests.get(f"API?page={i}").format(i)
    tenp_df = pd.DataFrame(response.json()['results'])
    df = df.append(tenp_df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for i in range(1,last+1):
#       2     response = requests.get(f"API?page={i}").format(i)
#       3     tenp_df = pd.DataFrame(response.json()['results'])
#
# NameError: name 'last' is not defined
